# %% [markdown]
# <a href="https://colab.research.google.com/github/mahendrarevino-jpg/Pemrograman-Dasar-/blob/main/Pertemuan_1_Malam_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Revino"
umur = 20
jurusan = "RPE"
semester = 3
matakuliah = 'pemegroman'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Revino
# 20
# RPE
# 3
# pemegroman
# False
