# %% [markdown]
# <a href="https://colab.research.google.com/github/mahendrarevino-jpg/Pemrograman-Dasar-/blob/main/PRAKTIKUM_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tegangan_volts = 18
arus_ampere = 6
jenis_sel = "Monocrystalline"

print(tegangan_volts)
print(arus_ampere)
print(jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
jumlah_resistor = 10
tegangan_dioda = 0.7
is_led_active = True
nama_mikrokontroler = "ESP32"

print(jumlah_resistor, type(jumlah_resistor))
print(tegangan_dioda, type(tegangan_dioda))
print(is_led_active, type(is_led_active))
print(nama_mikrokontroler, type(nama_mikrokontroler))
# Out:
# 10 <class 'int'>
# 0.7 <class 'float'>
# True <class 'bool'>
# ESP32 <class 'str'>

# %%
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# (a) Cetak pembacaan pertama dan terakhir memakai indeks
print("Pembacaan pertama:", tegangan_harian[0])
print("Pembacaan terakhir:", tegangan_harian[-1])

# (b) Tambahkan satu pembacaan baru 222.0 dengan append()
tegangan_harian.append(222.0)

# (c) Cetak jumlah total data dengan len()
print("Jumlah total data:", len(tegangan_harian))
# Out:
# Pembacaan pertama: 217.5
# Pembacaan terakhir: 216.9
# Jumlah total data: 7

# %%
# 1. Membuat dictionary spesifikasi motor listrik
motor_listrik = {
    "nama": "EM-Induction-X1",
    "daya_kW": 15.0,
    "tegangan_V": 380,
    "rpm": 1450
}

# 2. Mencetak salah satu nilai lewat key-nya (contoh: daya_kW)
print("Daya motor listrik:", motor_listrik["daya_kW"], "kW")

# 3. Mengubah nilai rpm menggunakan operator '='
motor_listrik["rpm"] = 3000

# 4. Mencetak ulang seluruh dictionary
print("\nSpesifikasi motor listrik setelah diperbarui:")
print(motor_listrik)
# Out:
# Daya motor listrik: 15.0 kW
#
# Spesifikasi motor listrik setelah diperbarui:
# {'nama': 'EM-Induction-X1', 'daya_kW': 15.0, 'tegangan_V': 380, 'rpm': 3000}

# %%
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]

# 1. Cetak nama unit kedua (indeks 1)
print("Nama unit kedua:", pembangkit[1]["nama"])

# 2. Ubah status salah satu unit (misal Unit-3)
pembangkit[2]["status"] = "operasi"

# 3. Tambahkan satu unit baru menggunakan append()
pembangkit.append({"nama": "Unit-4", "kapasitas_MW": 200, "status": "pemeliharaan"})

# 4. Cetak seluruh data
print("\nData seluruh pembangkit:")
for unit in pembangkit:
    print(unit)
# Out:
# Nama unit kedua: Unit-2
#
# Data seluruh pembangkit:
# {'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}
# {'nama': 'Unit-4', 'kapasitas_MW': 200, 'status': 'pemeliharaan'}
